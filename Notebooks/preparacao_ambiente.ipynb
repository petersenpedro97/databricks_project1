# %%
# %%sql
# CREATE CATALOG IF NOT EXISTS project1;

# %%
# %%sql
# CREATE SCHEMA IF NOT EXISTS project1.bronze;

# %%
# %%sql
# CREATE SCHEMA IF NOT EXISTS project1.silver;

# %%
# %%sql
# CREATE SCHEMA IF NOT EXISTS project1.gold;
